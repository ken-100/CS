# %%
# !python3 -m homework.visualize_data data/valid
# %matplotlib inline
# %run -m homework.visualize_data data/valid/
# Out:
# a

# %%
# Out:
# code here
# LinearClassifier(
#   (linear1): Linear(in_features=12288, out_features=6, bias=True)
# )
# times train: 100, Loss: 0.9368022084236145
# times train: 200, Loss: 0.7722898125648499
# times train: 300, Loss: 0.7160692811012268
# times train: 400, Loss: 0.9065519571304321
# times train: 500, Loss: 0.5339930653572083
# times train: 600, Loss: 0.7070745229721069
# times train: 700, Loss: 0.544708251953125
# times train: 800, Loss: 0.502905011177063
# times train: 900, Loss: 0.48893091082572937
# times train: 1000, Loss: 0.5131651759147644
# times train: 1100, Loss: 0.5513365268707275
# times train: 1200, Loss: 0.5894426703453064
# times train: 1300, Loss: 0.7161441445350647
# times train: 1400, Loss: 0.4597911536693573
# times train: 1500, Loss: 0.5902538895606995
# times train: 1600, Loss: 0.618039608001709
# total test loss: 104.21492004394531
# tensor(0.6452)

# %%
# !python3 -m homework.train -m linear
# %matplotlib inline
# %run -m homework.train -m linear
# Out:
# epoch 0   	 loss = 0.980 	 acc = 0.663 	 val acc = 0.679
# epoch 1   	 loss = 0.730 	 acc = 0.757 	 val acc = 0.711
# epoch 2   	 loss = 0.668 	 acc = 0.782 	 val acc = 0.745
# epoch 3   	 loss = 0.637 	 acc = 0.792 	 val acc = 0.735
# epoch 4   	 loss = 0.621 	 acc = 0.794 	 val acc = 0.723
# epoch 5   	 loss = 0.610 	 acc = 0.800 	 val acc = 0.739
# epoch 6   	 loss = 0.592 	 acc = 0.803 	 val acc = 0.743
# epoch 7   	 loss = 0.579 	 acc = 0.813 	 val acc = 0.743
# epoch 8   	 loss = 0.567 	 acc = 0.817 	 val acc = 0.745
# epoch 9   	 loss = 0.565 	 acc = 0.814 	 val acc = 0.761
# epoch 10  	 loss = 0.555 	 acc = 0.820 	 val acc = 0.724
# epoch 11  	 loss = 0.553 	 acc = 0.821 	 val acc = 0.744
# epoch 12  	 loss = 0.541 	 acc = 0.827 	 val acc = 0.755
# epoch 13  	 loss = 0.541 	 acc = 0.826 	 val acc = 0.759
# epoch 14  	 loss = 0.533 	 acc = 0.831 	 val acc = 0.756
# epoch 15  	 loss = 0.527 	 acc = 0.832 	 val acc = 0.753
# epoch 16  	 loss = 0.527 	 acc = 0.828 	 val acc = 0.761
# epoch 17  	 loss = 0.525 	 acc = 0.833 	 val acc = 0.754
# epoch 18  	 loss = 0.525 	 acc = 0.831 	 val acc = 0.765
# epoch 19  	 loss = 0.515 	 acc = 0.838 	 val acc = 0.760
# epoch 20  	 loss = 0.512 	 acc = 0.835 	 val acc = 0.767
# epoch 21  	 loss = 0.508 	 acc = 0.839 	 val acc = 0.770
# epoch 22  	 loss = 0.507 	 acc = 0.839 	 val acc = 0.762
# epoch 23  	 loss = 0.504 	 acc = 0.838 	 val acc = 0.763
# epoch 24  	 loss = 0.500 	 acc = 0.842 	 val acc = 0.766
# epoch 25  	 loss = 0.500 	 acc = 0.840 	 val acc = 0.760
# epoch 26  	 loss = 0.498 	 acc = 0.842 	 val acc = 0.771
# epoch 27  	 loss = 0.492 	 acc = 0.843 	 val acc = 0.766
# epoch 28  	 loss = 0.488 	 acc = 0.845 	 val acc = 0.758
# epoch 29  	 loss = 0.487 	 acc = 0.845 	 val acc = 0.769
# epoch 30  	 loss = 0.486 	 acc = 0.847 	 val acc = 0.740
# epoch 31  	 loss = 0.487 	 acc = 0.845 	 val acc = 0.760
# epoch 32  	 loss = 0.484 	 acc = 0.844 	 val acc = 0.765
# epoch 33  	 loss = 0.481 	 acc = 0.846 	 val acc = 0.775
# epoch 34  	 loss = 0.477 	 acc = 0.849 	 val acc = 0.770
# epoch 35  	 loss = 0.476 	 acc = 0.850 	 val acc = 0.771
# epoch 36  	 loss = 0.473 	 acc = 0.851 	 val acc = 0.767
# epoch 37  	 loss = 0.473 	 acc = 0.849 	 val acc = 0.770
# epoch 38  	 loss = 0.470 	 acc = 0.852 	 val acc = 0.765
# epoch 39  	 loss = 0.472 	 acc = 0.849 	 val acc = 0.759
# epoch 40  	 loss = 0.470 	 acc = 0.852 	 val acc = 0.757
# epoch 41  	 loss = 0.469 	 acc = 0.855 	 val acc = 0.776
# epoch 42  	 loss = 0.465 	 acc = 0.851 	 val acc = 0.767
# epoch 43  	 loss = 0.465 	 acc = 0.854 	 val acc = 0.775
# epoch 44  	 loss = 0.459 	 acc = 0.856 	 val acc = 0.763
# epoch 45  	 loss = 0.462 	 acc = 0.856 	 val acc = 0.773
# epoch 46  	 loss = 0.459 	 acc = 0.856 	 val acc = 0.772
# epoch 47  	 loss = 0.458 	 acc = 0.857 	 val acc = 0.777
# epoch 48  	 loss = 0.454 	 acc = 0.857 	 val acc = 0.758
# epoch 49  	 loss = 0.453 	 acc = 0.857 	 val acc = 0.765

# %%
# python3 -m homework.train -m mlp
# %matplotlib inline
# %run -m homework.train -m mlp
# Out:
# code here
# MLPClassifier(
#   (BN): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=12288, out_features=100, bias=True)
#   (relu): ReLU()
#   (linear2): Linear(in_features=100, out_features=6, bias=True)
# )
# times train: 100, Loss: 0.4906107187271118
# times train: 200, Loss: 0.5204586982727051
# times train: 300, Loss: 0.3737812340259552
# times train: 400, Loss: 0.4191645383834839
# times train: 500, Loss: 0.4272899031639099
# times train: 600, Loss: 0.31056302785873413
# times train: 700, Loss: 0.25162360072135925
# times train: 800, Loss: 0.21615441143512726
# times train: 900, Loss: 0.31407269835472107
# times train: 1000, Loss: 0.2526710331439972
# times train: 1100, Loss: 0.2632483243942261
# times train: 1200, Loss: 0.1630874127149582
# times train: 1300, Loss: 0.15261416137218475
# times train: 1400, Loss: 0.21533019840717316
# times train: 1500, Loss: 0.1793055534362793
# times train: 1600, Loss: 0.17931418120861053
# total test loss: 36.50052261352539
# tensor(0.8209)

# %%
# !python -m grader homework -v
# Out:
# Loading assignment
# a
# Loading grader
#  * SuperTuxDataset
#   - SuperTuxDataset.__getitem__                        [ passed ]
#   - image statistics                                   [ passed ]
#   - label statistics                                   [ passed ]
#   - SuperTuxDataset.__len__                            [ passed ]
#  --------------------------------------------------    [  15 /  15 ]
#
#  * LinearModel
#   - Linearity                                          [ passed ]
#   - Shape                                              [ passed ]
#  --------------------------------------------------    [  15 /  15 ]
#
#  * Loss
#   - ClassificationLoss.forward                         [ passed ]
#  --------------------------------------------------    [  10 /  10 ]
#
#  * TrainedLinearModel
#   - Accuracy                                           [ accuracy = 0.765 ]
#  --------------------------------------------------    [  30 /  30 ]
#
#  * TrainedMLPModel
#   - Accuracy                                           [ accuracy = 0.821 ]
#  --------------------------------------------------    [  30 /  30 ]
#
#
# total score                                              100 / 100

# %%
# !python3 bundle.py homework ky5697
# %matplotlib inline
# %run bundle.py homework ky5697
# Out:
# submission created for ky5697.zip. Please remember to submit
